# %% [markdown]
# # Timer

# %%
import time

start_time = time.time()

for i in range(1000000):
    pass

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Elasped time: {elapsed_time:.3f} s")
# Out:
# Elasped time: 0.095 s
